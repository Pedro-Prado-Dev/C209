# %% [markdown]
# +# Instruções da prova
#
# - O único material que poderá ser consultado é este notebook, consultas à outros materiais ou à internet será considerado cola
# - Renomear o notebook para C209-PV1.1-NOME_SOBRENOME_MATRICULA
# - Enviar no teams a pasta com todas as mídias zipada com o nome "NOME_SOBRENOME_MATRICULA.zip"

# %% [markdown]
# # Parte Teórica

# %% [markdown]
# Classifique as afirmações em Verdadeiro ou Falso, justifique as afirmativas falsas, escreva suas respostas nos campos disponíveis com um '#" na frente de seu texto

# %% [markdown]
# 1 - Imagens negativas são resultantes da operação "E" entre duas imagens

# %%
# F - Imagens negativas são resultantes da operação NOT

# %% [markdown]
# 2 - A conversão entre RGB e CMY é simples pois tratam-se de espaços de cores complementares

# %%
# V

# %% [markdown]
# 3 - O código abaixo representa um retângulo com o centro na posição (128,190), altura de 120px e largura de 64px:
#
#     "<rect x="128" y="190" width="64" height="120" fill="black"/>"

# %%
# V

# %% [markdown]
# 4 - Imagens em grayscale possuem 3 páginas de cor porém todas estão em escala de cinza

# %%
# V

# %% [markdown]
# 5 - Operações geométricas são aquelas que consistem na mudança espacial de pixels

# %%
# V

# %% [markdown]
# # Parte Prática

# %% [markdown]
# ### Material de apoio

# %% [markdown]
# ### Importações
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
# from PIL import Image
# ```
#
# ### Manipulação de imagens
#
# ```
# img = Image.open('nome.extensão')
# img = np.array(Image.open('nome.extensão'))
# img = img[:, :, :3]
# img_pil = Image.fromarray(img_np)
# img.save('nome.png')
# Image.fromarray(img).save('nome_arquivo.extensao')
# (l,c,p) = img.shape
# ```
#
# ### Exibição de imagens
#
# ```
# plt.figure(figsize=(8, 8))
# plt.subplot(2, 2, 1)
# plt.imshow(img1)
# plt.subplot(2, 2, 2)
# plt.imshow(img2)
# ```
#
# ### Reflexão
#
#
# #### Alt1
# ```
# mario_refl = np.zeros(shape=mario.shape, dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         new_x = -j
#         new_y = i
#         mario_refl[new_y, new_x] = mario[i, j]
# ```
#
# #### Alt2
# ```
# mario_refl = np.zeros(shape=mario.shape, dtype=np.uint8)
# mario_refl[::1, ::-1] = mario
# ```
#
# ### Greyscale
#
# #### Algoritmo genérico, substituir o método escolhido
# ```
# img_avg = np.zeros(shape=(l, c), dtype=np.uint8)
# for i in range(l):
#     for j in range(c):
#         r = float(img_np[i, j, 0])
#         g = float(img_np[i, j, 1])
#         b = float(img_np[i, j, 2])
#
#         img_avg[i, j] = (aplicar método)
# ```
#
# #### Métodos:
#
# Lightness: $\frac{max(R,G,B)+min(R,G,B)}{2}$
#
# Average: $\frac{R+G+B}{3}$
#
# Luminosity: $0.2126 \cdot R + 0.7152 \cdot G + 0.0722 \cdot B$
#
# ### Escalonamento com nearest neighbor
#
# ```
# ls, cs = l * sy, c * sx
# mario_nn = np.zeros(shape=(ls, cs, p), dtype=np.uint8)
#
# for i in range(ls):
#     for j in range(cs):
#         new_y = int(np.floor(i * (l / ls)))
#         new_x = int(np.floor(j * (c / cs)))
#
#         mario_nn[i, j] = mario[new_y, new_x]
# ```
#
# ### Rotação com interpolação
#
# ```
# alpha = np.pi / 6 # 30°
#
# ls, cs = int(l * np.sqrt(2)), int(c * np.sqrt(2))
# mario_rot = np.zeros((ls, cs, p), dtype=np.uint8)
# for i in range(ls):
#     for j in range(cs):
#         cx = j - (ls / 2)
#         cy = i - (cs / 2)
#
#         new_x = int( cx * np.cos(alpha) + cy * np.sin(alpha) + l / 2)
#         new_y = int(-cx * np.sin(alpha) + cy * np.cos(alpha) + c / 2)
#
#         if 0 <= new_x < c and 0 <= new_y < l:
#             mario_rot[i, j] = mario[new_y, new_x]
# ```

# %% [markdown]
# **1 -** Importe as bibliotecas que serão usadas

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# **2 -** Abra as imagens mustache.jpg e shrek.png, retire o canal alpha (se necessário), exiba essas imagens e mostre o formato de cada uma

# %%
img_1 = np.array(Image.open('mustache.jpg'))
print(img_1.shape) #Imprime o valor matricial [310, 550, 3] -----> Não há canal alfa

img_2 = np.array(Image.open('shrek.png'))
print(img_2.shape) #Imprime o valor matricial [310, 550, 3] -----> Não há canal alfa

plt.figure(figsize=(8, 8))
plt.subplot(2, 2, 1)
plt.imshow(img_1)
plt.subplot(2, 2, 2)
plt.imshow(img_2)
# Out:
# (400, 400, 3)
# (200, 200, 3)

# %% [markdown]
# **3 -** Crie uma função que realize a reflexão no eixo x. Essa função deve receber uma **imagem como parâmetro** e **retornar uma imagem refletida no eixo x**. Aplique essa função na imagem "mustache" aberta na questão anterior e mostre o resultado.

# %%
def reflexao(img):
    img_refl = np.zeros(shape=img.shape, dtype=np.uint8)
    img_refl[::-1, ::1] = img
    return img_refl    
    
img_1 = np.array(Image.open('mustache.jpg'))
print(img_1.shape)
    
mustache_rflx = reflexao(img_1) 
plt.imshow(mustache_rflx)
# Out:
# (400, 400, 3)

# %% [markdown]
# **4 -** Realize a operação lógica NOT com a imagem da questão anterior e mostre o resultado

# %%
bin_not = np.invert(mustache_rflx)
plt.imshow(bin_not)

# %% [markdown]
# **5 -** Crie uma função que realize o escalonamento de uma imagem que receba como parâmetro uma **imagem, sx e sy**, sendo sx e sy os fatores de escalonamento e **retorne a imagem escalonada**, em seguida aplique o escalonamento na imagem "shrek" para que fique do mesmo tamanho da imagem da questão anterior. Exiba o resultado.

# %%
def escalonamento (img, sx, sy):

    (l,c,p) = img.shape
    ls, cs = l * sy, c * sx
    img_escl = np.zeros(shape=(ls, cs, p), dtype=np.uint8)

    for i in range(ls):
        for j in range(cs):
            new_y = int(np.floor(i * (l / ls)))
            new_x = int(np.floor(j * (c / cs)))
    
            img_escl[i, j] = img[new_y, new_x]
    return img_escl

result = escalonamento(img_2,2,2) 

plt.figure(figsize=(8, 8))
plt.subplot(2, 2, 1)
plt.imshow(img_2)
plt.subplot(2, 2, 2)
plt.imshow(result)

# %% [markdown]
# **6 -** Realize o mascaramento (lógica E) entre as imagens das questões 4 e 5, exiba o resultado.

# %%
logic_and = bin_not & result 
plt.imshow(logic_and)

# %% [markdown]
# **7 -** Crie uma função para aplicar um método grayscale de sua escolha, que receba como parâmetro uma imagem e retorne uma imagem em greyscale. Aplique essa função na imagem resultante da questão anterior e mostre o resultado.

# %%
def grayscale(img):
    
    img_gray = np.zeros(shape=(l, c), dtype=np.uint8)
    for i in range(l):
        for j in range(c):
            r = float(img[i, j, 0])
            g = float(img[i, j, 1])
            b = float(img[i, j, 2])
            img_gray[i, j] = (r + g + b) / 3
            
    return img_gray

image_gray = grayscale(logic_and)
plt.imshow(image_gray, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pedro\Downloads\Provas_Passadas_C209_LAB\ProvaAvner1.2\C209_PL1.ipynb Célula: 30 in <cell line: 13>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a>             img_gray[i, j] = (r + g + b) / 3
#      <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a>     return img_gray
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=12'>13</a> image_gray = grayscale(logic_and)
#      <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=13'>14</a> plt.imshow(image_gray, cmap = 'gray')
#
# c:\Users\pedro\Downloads\Provas_Passadas_C209_LAB\ProvaAvner1.2\C209_PL1.ipynb Célula: 30 in grayscale(img)
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> def grayscale(img):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a>     img_gray = np.zeros(shape=(l, c), dtype=np.uint8)
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a>     for i in range(l):
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a>         for j in range(c):
#
# NameError: name 'l' is not defined

# %% [markdown]
# **8 -** Crie uma função que realize uma rotação com interpolação, a função deve receber como parâmetro **uma imagem e o ângulo alpha com que deve ser rotacionada** e **retornar uma imagem rotacionada com o angulo alpha**. Modifique o algoritmo de rotação para que funcione se necessário. Aplique a função na imagem resultante da questão anterior **com ângulo de 60°** e mostre o resultado.

# %%
def interpol(img,angl):
    (l,c,p)=img.shape
    anglo = angl
    definir_ang = 180/anglo
    alpha = np.pi / definir_ang 

    ls, cs = int(l * np.sqrt(2)), int(c * np.sqrt(2))
    img_interpol = np.zeros((ls, cs, p), dtype=np.uint8)
    for i in range(ls):
        for j in range(cs):
            cx = j - (ls / 2)
            cy = i - (cs / 2)

            new_x = int( cx * np.cos(alpha) + cy * np.sin(alpha) + l / 2)
            new_y = int(-cx * np.sin(alpha) + cy * np.cos(alpha) + c / 2)

            if 0 <= new_x < c and 0 <= new_y < l:
                img_interpol[i, j] = img[new_y, new_x]
                
    return img_interpol


imagem_final = interpol(logic_and,60)
plt.imshow(imagem_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pedro\Downloads\Provas_Passadas_C209_LAB\ProvaAvner1.2\C209_PL1.ipynb Célula: 32 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X43sZmlsZQ%3D%3D?line=17'>18</a>                 img_interpol[i, j] = img[new_y, new_x]
#      <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X43sZmlsZQ%3D%3D?line=19'>20</a>     return img_interpol
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X43sZmlsZQ%3D%3D?line=22'>23</a> imagem_final = interpol(logic_and,60)
#      <a href='vscode-notebook-cell:/c%3A/Users/pedro/Downloads/Provas_Passadas_C209_LAB/ProvaAvner1.2/C209_PL1.ipynb#X43sZmlsZQ%3D%3D?line=23'>24</a> plt.imshow(imagem_final)
#
# NameError: name 'logic_and' is not defined

# %% [markdown]
# **9 -** Salve a imagem da questão anterior no disco com o nome "resultado.jpg"

# %%
Image.fromarray(imagem_final).save('resultado.jpg')
